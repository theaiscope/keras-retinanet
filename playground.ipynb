# %%
# %load_ext autoreload
# %autoreload 2
from keras_retinanet.preprocessing.detgen import DetDataGenerator
from keras_retinanet.preprocessing.csv_generator import CSVGenerator
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from detdata import DetGen
from detdata.augmenters import dummy, crazy_augmenter

g = CSVGenerator('/home/i008/googledrive/Projects/AiScope/retina_train.csv', 
            '/home/i008/googledrive/Projects/AiScope/retina_labels.csv', batch_size=4)

# %%
detg= DetGen('/home/i008/malaria_data/dataset_train.mxrecords',
      '/home/i008/malaria_data/dataset_train.csv',
      '/home/i008/malaria_data/dataset_valid.mxindex', batch_size=4)
mxg = DetDataGenerator(detg, augmenter=crazy_augmenter)
mxg.image_max_side = 750
mxg.image_min_side = 750

# %%
a, (b, c) = next(g)
# Out:
# /home/i008/googledrive/Projects/keras-retinanet/keras_retinanet/preprocessing/generator.py:106: UserWarning: Image with id 464 (shape (750, 750, 3)) contains the following invalid boxes: [array([485., 716., 525., 756.,   0.])].
#   [annotations[invalid_index, :] for invalid_index in invalid_indices]
# /home/i008/googledrive/Projects/keras-retinanet/keras_retinanet/preprocessing/generator.py:106: UserWarning: Image with id 466 (shape (750, 750, 3)) contains the following invalid boxes: [array([ 93., 714., 133., 754.,   0.])].
#   [annotations[invalid_index, :] for invalid_index in invalid_indices]

# %%
aa, (bb, cc) = next(mxg)
# Out:
# /home/i008/anaconda3/lib/python3.6/site-packages/mxnet/recordio.py:370: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   header = header._replace(label=np.fromstring(s, np.float32, header.flag))
# /home/i008/anaconda3/lib/python3.6/site-packages/mxnet/recordio.py:412: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   img = np.fromstring(s, dtype=np.uint8)

# %%
# %matplotlib inline
plt.imshow(aa[0].astype('uint8'))

# %%
aa[0]
# Out:
# array([[[ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         ...,
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997]],
#
#        [[ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         ...,
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997]],
#
#        [[ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         [ 85.061    ,  20.221    ,   0.3199997],
#         ...,
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997],
#         [103.061    ,  33.221    ,   5.3199997]],
#
#        ...,
#
# ...
